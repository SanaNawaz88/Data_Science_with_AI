# %%
#Categorical Nmerical
import matplotlib.pyplot as plt
x=["Sana","Sara","Saba"]
y=[10,20,30]
plt.bar(x,y,color="red")
plt.xlabel("X-axis",fontsize=10)
plt.ylabel("Y-axis",fontsize=10)
plt.title("Data Visalization(Bar Plot)")
plt.show()
